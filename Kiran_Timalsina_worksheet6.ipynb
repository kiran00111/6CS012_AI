# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

train_dir = '/content/drive/MyDrive/FruitinAmazon/train'
test_dir = '/content/drive/MyDrive/FruitinAmazon/test'

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the train directory path
train_dir = '/content/drive/MyDrive/FruitinAmazon/train'

# Get the list of class directories
class_dirs = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]
class_dirs.sort()  # Sort for consistent order
print(f"Found {len(class_dirs)} classes: {class_dirs}")

# Select one random image from each class
images = []
class_names = []
for class_dir in class_dirs:
    class_path = os.path.join(train_dir, class_dir)
    image_files = [f for f in os.listdir(class_path) if f.endswith(('.jpg', '.jpeg', '.png'))]
    if image_files:  # Ensure there’s at least one image
        random_image = random.choice(image_files)
        image_path = os.path.join(class_path, random_image)
        images.append(image_path)
        class_names.append(class_dir)

# Check if we have images to display
if not images:
    raise ValueError("No images found in the dataset!")

# Display images in a 2-row grid
rows = 2
cols = (len(images) + 1) // 2  # Ceiling division to fit all classes
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))  # Adjust figure size as needed
fig.suptitle("Random Images from Each Class", fontsize=16)

# Flatten axes array for easier indexing
axes = axes.flatten()

# Plot each image
for i, (image_path, class_name) in enumerate(zip(images, class_names)):
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].set_title(class_name)
    axes[i].axis('off')  # Hide axes

# Hide any unused subplots (if odd number of classes)
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %%
import os
from PIL import Image, UnidentifiedImageError

corrupted_images = []  # List to store corrupted image paths

# Loop through each class folder and check for corrupted images
for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)

    if os.path.isdir(class_path):  # Ensure it’s a valid directory
        images = os.listdir(class_path)

        for img_name in images:
            img_path = os.path.join(class_path, img_name)

            try:
                with Image.open(img_path) as img:
                    img.verify()  # Verify image integrity
            except (IOError, UnidentifiedImageError):
                corrupted_images.append(img_path)

# Print results
if corrupted_images:
    print("\nCorrupted Images Found:")
    for img in corrupted_images:
        print(img)
else:
    print("\nNo corrupted images found.")
# Out:
# No corrupted images found.

# %%
image_size = (28, 28)
batch_size = 32
train_ds, val_ds = keras.utils.image_dataset_from_directory(
   train_dir,
   validation_split=0.2,
   subset="both",
   seed=1337,
   image_size=image_size,
   batch_size=batch_size,
)
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Using 18 files for validation.

# %%
for images, labels in train_ds.take(1): # Take one batch
 print("Images shape:", images.shape)
 print("Labels shape:", labels.shape)
# Out:
# Images shape: (32, 28, 28, 3)
# Labels shape: (32,)

# %%
plt.figure(figsize=(10, 10))

# Take one batch of images from the dataset (train_ds)
for images, labels in train_ds.take(1):
    for i in range(9):  # Displaying first 9 images
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))  # Convert to uint8 for display
        plt.title(int(labels[i]))  # Convert label to integer
        plt.axis("off")  # Hide axes

plt.show()  # Display the figure

# %%
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Define image size and batch size
img_size = (224, 224)
batch_size = 32

# Load train and test datasets
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=img_size,
    batch_size=batch_size  # Corrected parameter name
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    shuffle=False,
    image_size=img_size,
    batch_size=batch_size  # Corrected parameter name
)

# Define data augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# Visualizing augmented images
def visualization(dataset):
    plt.figure(figsize=(7, 7))

    for images, _ in dataset.take(1):  # Take one batch
        for i in range(6):  # Show 6 images
            image = tf.expand_dims(images[i], axis=0)  # Expand dimensions to match batch format
            augmented_img = data_augmentation(image)  # Apply augmentation
            augmented_img = tf.squeeze(augmented_img)  # Remove batch dimension

            plt.subplot(3, 3, i + 1)
            plt.imshow(augmented_img.numpy().astype("uint8"))
            plt.axis("off")

    plt.show()

# Call the function (must be outside the function definition)
visualization(train_dataset)
# Out:
# Found 90 files belonging to 6 classes.
# Found 30 files belonging to 6 classes.

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
]

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, Lambda, Rescaling
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
]

def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

# Define the model using the Sequential API with a list of layers
model = Sequential([
    # Data augmentation applied using Lambda layer
    layers.Lambda(data_augmentation, input_shape=(224, 224, 3)),
    # Rescaling layer to normalize pixel values
    layers.Rescaling(1./255),
    # First Convolutional Block
    Conv2D(32, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    # Second Convolutional Block
    Conv2D(64, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    # Third Convolutional Block
    Conv2D(128, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    # Fourth Convolutional Block
    Conv2D(256, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    # Flatten the output of the last Conv2D layer
    Flatten(),
    # First Fully Connected Layer
    Dense(512, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    # Second Fully Connected Layer
    Dense(256, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    # Third Fully Connected Layer
    Dense(128, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    # Fourth Fully Connected Layer
    Dense(64, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    # Output Layer with 10 neurons (for classification task with 10 classes)
    Dense(10, activation='softmax')
])

# Compile the model with Adam optimizer, sparse categorical crossentropy loss, and accuracy as the metric
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # Use this for integer labels
              metrics=['accuracy'])


# Summary of the model
model.summary()

checkpoint = ModelCheckpoint(
    'best_model.keras',  # Save best model
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=20,  # Stop after 20 epochs with no improvement
    mode='max',
    verbose=1
)
# Train model
histroy = model.fit(
    train_dataset,
    epochs=50,
    validation_data=test_dataset,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                      │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 224, 224, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 512)                 │      25,690,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_7 (Activation)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,257,930 (100.17 MB)
#  Trainable params: 26,255,050 (100.16 MB)
#  Non-trainable params: 2,880 (11.25 KB)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1010 - loss: 3.1479
# Epoch 1: val_accuracy improved from -inf to 0.10000, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 48s 15s/step - accuracy: 0.1008 - loss: 3.1038 - val_accuracy: 0.1000 - val_loss: 2.3466
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.0832 - loss: 3.1006
# Epoch 2: val_accuracy improved from 0.10000 to 0.16667, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 9s/step - accuracy: 0.0819 - loss: 3.0908 - val_accuracy: 0.1667 - val_loss: 2.3184
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.0876 - loss: 2.9045
# Epoch 3: val_accuracy did not improve from 0.16667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 26s 8s/step - accuracy: 0.0963 - loss: 2.8820 - val_accuracy: 0.1667 - val_loss: 2.2676
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2051 - loss: 2.5034
# Epoch 4: val_accuracy improved from 0.16667 to 0.20000, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 42s 9s/step - accuracy: 0.1983 - loss: 2.5217 - val_accuracy: 0.2000 - val_loss: 2.2436
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1084 - loss: 2.7455
# Epoch 5: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 39s 8s/step - accuracy: 0.1119 - loss: 2.7550 - val_accuracy: 0.1667 - val_loss: 2.2510
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1137 - loss: 2.7057
# Epoch 6: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 8s/step - accuracy: 0.1158 - loss: 2.7089 - val_accuracy: 0.1667 - val_loss: 2.2592
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1486 - loss: 2.7972
# Epoch 7: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 9s/step - accuracy: 0.1448 - loss: 2.7975 - val_accuracy: 0.1667 - val_loss: 2.2562
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1211 - loss: 2.5310
# Epoch 8: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 37s 8s/step - accuracy: 0.1269 - loss: 2.5184 - val_accuracy: 0.1667 - val_loss: 2.2429
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2288 - loss: 2.5733
# Epoch 9: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 8s/step - accuracy: 0.2299 - loss: 2.5748 - val_accuracy: 0.1667 - val_loss: 2.2413
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2028 - loss: 2.4961
# Epoch 10: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 24s 8s/step - accuracy: 0.2104 - loss: 2.4674 - val_accuracy: 0.1667 - val_loss: 2.2474
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2764 - loss: 2.1251
# Epoch 11: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 42s 9s/step - accuracy: 0.2740 - loss: 2.1217 - val_accuracy: 0.1667 - val_loss: 2.2577
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2192 - loss: 2.2519
# Epoch 12: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step - accuracy: 0.2116 - loss: 2.2505 - val_accuracy: 0.1667 - val_loss: 2.2853
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2258 - loss: 2.1875
# Epoch 13: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 8s/step - accuracy: 0.2332 - loss: 2.1854 - val_accuracy: 0.1667 - val_loss: 2.3145
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2451 - loss: 1.9377
# Epoch 14: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 8s/step - accuracy: 0.2505 - loss: 1.9430 - val_accuracy: 0.1667 - val_loss: 2.3566
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.3916 - loss: 1.8534
# Epoch 15: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 39s 9s/step - accuracy: 0.3881 - loss: 1.8571 - val_accuracy: 0.1667 - val_loss: 2.4104
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.3083 - loss: 2.0497
# Epoch 16: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 8s/step - accuracy: 0.3063 - loss: 2.0590 - val_accuracy: 0.1667 - val_loss: 2.4824
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.3722 - loss: 1.8849
# Epoch 17: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 42s 8s/step - accuracy: 0.3708 - loss: 1.8833 - val_accuracy: 0.1667 - val_loss: 2.5774
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.3909 - loss: 1.8010
# Epoch 18: val_accuracy did not improve from 0.20000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 8s/step - accuracy: 0.3793 - loss: 1.8324 - val_accuracy: 0.1667 - val_loss: 2.6647
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.3722 - loss: 1.9353
# Epoch 19: val_accuracy improved from 0.20000 to 0.23333, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 47s 11s/step - accuracy: 0.3708 - loss: 1.9202 - val_accuracy: 0.2333 - val_loss: 2.7400
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.3781 - loss: 1.7660
# Epoch 20: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 38s 10s/step - accuracy: 0.3836 - loss: 1.7553 - val_accuracy: 0.2333 - val_loss: 2.7861
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4116 - loss: 1.7455
# Epoch 21: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 37s 8s/step - accuracy: 0.4142 - loss: 1.7293 - val_accuracy: 0.2333 - val_loss: 2.8417
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5216 - loss: 1.5199
# Epoch 22: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.5051 - loss: 1.5279 - val_accuracy: 0.2333 - val_loss: 2.9555
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4563 - loss: 1.5661
# Epoch 23: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 8s/step - accuracy: 0.4422 - loss: 1.5890 - val_accuracy: 0.1667 - val_loss: 3.1171
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5319 - loss: 1.4288
# Epoch 24: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 42s 9s/step - accuracy: 0.5323 - loss: 1.4216 - val_accuracy: 0.1667 - val_loss: 3.3295
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4926 - loss: 1.4313
# Epoch 25: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 10s/step - accuracy: 0.4889 - loss: 1.4371 - val_accuracy: 0.1667 - val_loss: 3.4843
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5536 - loss: 1.3999
# Epoch 26: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 38s 9s/step - accuracy: 0.5374 - loss: 1.4210 - val_accuracy: 0.1667 - val_loss: 3.5797
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5847 - loss: 1.3222
# Epoch 27: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 26s 9s/step - accuracy: 0.5802 - loss: 1.3230 - val_accuracy: 0.1667 - val_loss: 3.6649
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4933 - loss: 1.5166
# Epoch 28: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step - accuracy: 0.4977 - loss: 1.5186 - val_accuracy: 0.1667 - val_loss: 3.6609
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5550 - loss: 1.2649
# Epoch 29: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step - accuracy: 0.5551 - loss: 1.2766 - val_accuracy: 0.1667 - val_loss: 3.7059
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4829 - loss: 1.4808
# Epoch 30: val_accuracy did not improve from 0.23333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 8s/step - accuracy: 0.4899 - loss: 1.4631 - val_accuracy: 0.1667 - val_loss: 3.7462
# Epoch 31/50

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

# Load VGG16 base model (without top, pretrained on ImageNet)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze all convolutional layers

# Add custom head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(10, activation='softmax')(x)

# Create model (this was the part that broke)
model = Model(inputs=base_model.input, outputs=predictions)

# NOW we compile it (without any misplaced arguments)
model.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
checkpoint = ModelCheckpoint(
    'vgg16_best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    mode='max',
    verbose=1
)

# Train
history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=test_dataset,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.1389 - loss: 12.4592
# Epoch 1: val_accuracy improved from -inf to 0.10000, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 99s 39s/step - accuracy: 0.1458 - loss: 12.1583 - val_accuracy: 0.1000 - val_loss: 3.8414
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.1856 - loss: 9.4257
# Epoch 2: val_accuracy improved from 0.10000 to 0.30000, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 122s 29s/step - accuracy: 0.2003 - loss: 9.3772 - val_accuracy: 0.3000 - val_loss: 2.5176
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.2771 - loss: 6.4354
# Epoch 3: val_accuracy improved from 0.30000 to 0.40000, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 79s 27s/step - accuracy: 0.2828 - loss: 6.3116 - val_accuracy: 0.4000 - val_loss: 2.2628
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.2741 - loss: 5.1945
# Epoch 4: val_accuracy improved from 0.40000 to 0.43333, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 84s 27s/step - accuracy: 0.2861 - loss: 5.0806 - val_accuracy: 0.4333 - val_loss: 2.0576
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.3566 - loss: 5.2455
# Epoch 5: val_accuracy improved from 0.43333 to 0.46667, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 81s 28s/step - accuracy: 0.3591 - loss: 5.1829 - val_accuracy: 0.4667 - val_loss: 2.0433
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.4487 - loss: 3.3726
# Epoch 6: val_accuracy improved from 0.46667 to 0.50000, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 83s 28s/step - accuracy: 0.4504 - loss: 3.2967 - val_accuracy: 0.5000 - val_loss: 1.9013
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.4205 - loss: 3.1472
# Epoch 7: val_accuracy improved from 0.50000 to 0.53333, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 82s 28s/step - accuracy: 0.4237 - loss: 3.1198 - val_accuracy: 0.5333 - val_loss: 1.7129
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21s/step - accuracy: 0.3855 - loss: 3.1514
# Epoch 8: val_accuracy did not improve from 0.53333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 87s 31s/step - accuracy: 0.3947 - loss: 3.0563 - val_accuracy: 0.5333 - val_loss: 1.5834
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.5595 - loss: 1.9777
# Epoch 9: val_accuracy improved from 0.53333 to 0.63333, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 78s 28s/step - accuracy: 0.5502 - loss: 1.9907 - val_accuracy: 0.6333 - val_loss: 1.4916
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.6731 - loss: 1.1313
# Epoch 10: val_accuracy improved from 0.63333 to 0.66667, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 80s 28s/step - accuracy: 0.6660 - loss: 1.1760 - val_accuracy: 0.6667 - val_loss: 1.4226
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.6286 - loss: 1.1638
# Epoch 11: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 84s 29s/step - accuracy: 0.6187 - loss: 1.2031 - val_accuracy: 0.6333 - val_loss: 1.3880
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.6775 - loss: 1.3338
# Epoch 12: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 80s 28s/step - accuracy: 0.6804 - loss: 1.2992 - val_accuracy: 0.6667 - val_loss: 1.4233
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.6723 - loss: 1.2129
# Epoch 13: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 80s 28s/step - accuracy: 0.6765 - loss: 1.1919 - val_accuracy: 0.6667 - val_loss: 1.3992
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.7385 - loss: 0.8044
# Epoch 14: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 95s 38s/step - accuracy: 0.7289 - loss: 0.8364 - val_accuracy: 0.6667 - val_loss: 1.4369
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.7266 - loss: 0.8378
# Epoch 15: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 124s 29s/step - accuracy: 0.7227 - loss: 0.8617 - val_accuracy: 0.6667 - val_loss: 1.5233
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.7809 - loss: 0.7051
# Epoch 16: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 76s 28s/step - accuracy: 0.7690 - loss: 0.7293 - val_accuracy: 0.6667 - val_loss: 1.5752
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.7236 - loss: 0.9369
# Epoch 17: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 82s 28s/step - accuracy: 0.7260 - loss: 0.9243 - val_accuracy: 0.6667 - val_loss: 1.6222
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.7868 - loss: 0.6973
# Epoch 18: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 74s 27s/step - accuracy: 0.7818 - loss: 0.7152 - val_accuracy: 0.6333 - val_loss: 1.6283
# Epoch 19/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.7050 - loss: 0.7961
# Epoch 19: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 83s 28s/step - accuracy: 0.7176 - loss: 0.7891 - val_accuracy: 0.6333 - val_loss: 1.6122
# Epoch 20/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.8157 - loss: 0.7272
# Epoch 20: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 83s 28s/step - accuracy: 0.8174 - loss: 0.7074 - val_accuracy: 0.5667 - val_loss: 1.6099
# Epoch 20: early stopping

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np

# Get predictions
y_true = np.concatenate([y for _, y in test_dataset], axis=0)
y_pred_probs = model.predict(test_dataset)
y_pred = np.argmax(y_pred_probs, axis=1)

# Report
print(classification_report(y_true, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step
#               precision    recall  f1-score   support
#
#            0       0.25      0.20      0.22         5
#            1       0.67      0.80      0.73         5
#            2       0.71      1.00      0.83         5
#            3       0.80      0.80      0.80         5
#            4       0.00      0.00      0.00         5
#            5       0.38      0.60      0.46         5
#
#     accuracy                           0.57        30
#    macro avg       0.47      0.57      0.51        30
# weighted avg       0.47      0.57      0.51        30
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
